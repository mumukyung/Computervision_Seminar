# %% [markdown]
# <a href="https://colab.research.google.com/github/mumukyung/Computervision_Seminar/blob/main/modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CV_seminar_project
# Out:
# /content/drive/MyDrive/CV_seminar_project

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/CV_seminar_project'

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu' # device 배정
torch.manual_seed(42)
if device == 'cuda':
  torch.cuda.manual_seed_all(42)
device
# Out:
# 'cuda'

# %% [markdown]
# # 1. 데이터 셋 준비하기

# %%
import torch.nn as nn

# 하이퍼 파라미터
batch_size = 8
lr = 0.0001
epochs = 50
optimizer_name = 'adam'
model_name = 'resnet50'
criterion = nn.CrossEntropyLoss().to(device) # cost function

# %%
from dataset import Custom_dataset as C
from torch.utils.data import Dataset, DataLoader
import cv2
import os 
import torch
import torchvision
from torchvision import transforms # 이미지 데이터 augmentation
import glob
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2 # albumentations 텐서화 함수

root_path = '/content/drive/MyDrive/CV_seminar_project'

train_transforms = A.Compose([
    A.Resize(224,224),
    A.Transpose(p=0.5),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.ShiftScaleRotate(p=0.5),
    A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=20, val_shift_limit=20, p=0.5),
    A.RandomBrightnessContrast(brightness_limit=(-0.1,0.1), contrast_limit=(-0.1, 0.1), p=0.5),
    A.ChannelShuffle(),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0), # 이미지넷 데이터셋 통계값으로 Normalize
    A.CoarseDropout(p=0.5),
    ToTensorV2()
])

test_transforms = A.Compose([
    A.Resize(224,224),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0), # 텐서타입은 안해줌
    ToTensorV2() # Normalize를 먼저하고 tensor화를 진행해야한다.
])

### Pytorch 데이터 클래스 생성
train_class = C(root_path=root_path, mode='train', transforms=train_transforms)
valid_class = C(root_path=root_path, mode='valid', transforms=test_transforms)
test_class = C(root_path=root_path, mode='test', transforms=test_transforms)

### Pytorch BatchLoader 생성 (학습에 이용할 최종 dataloader)
from torch.utils.data import DataLoader as DataLoader

train_loader = DataLoader(train_class, batch_size=batch_size, shuffle = True, num_workers=0)
valid_loader = DataLoader(valid_class, batch_size=batch_size, shuffle = False, num_workers=0)
test_loader = DataLoader(test_class, batch_size=batch_size, shuffle = False, num_workers=0)

# %% [markdown]
# # 2. 모델 불러오기

# %%
from torchvision import models # 모델 라이브러리 함수

resnet_50 = models.resnet50(pretrained=True).to(device) # 선행학습 여부

# finetuning
import torch.nn as nn # 파이토치 뉴럴네트워크 layer 라이브러리
resnet_50.fc = nn.Linear(resnet_50.fc.in_features, 3).to(device)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
from torchsummary import summary # 모델 아키텍쳐 확인하는 함수

summary(resnet_50, input_size = (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                    [-1, 3]           6,147
# ================================================================
# Total params: 23,514,179
# Trainable params: 23,514,179
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.55
# Params size (MB): 89.70
# Estimated Total Size (MB): 376.82
# ----------------------------------------------------------------

# %%
optimizer = torch.optim.Adam(resnet_50.parameters(), lr = lr, weight_decay = 1e-8)

# %% [markdown]
# # 3. 모델 학습시키기
#
# 모델 저장하기 ; 딕셔너리 형식의 pth 확장자로 저장이 된다.
# validation set의 성능이 어디까지 epoch의 성능에서 best일때의 모델의 가중치를 저장한다.

# %%
import numpy as np
train_acc_lst = []
train_loss_lst = []

test_acc_lst = []
test_loss_lst = []
epochs = 100

save_dir =  '/content/drive/MyDrive/CV_seminar_project'
model_name = 'resnet50'

for epoch in range(1, epochs):
  running_loss = 0.0
  test_running_loss = 0.0

  total = 0
  correct = 0
  
  train_acc = 0
  test_acc = 0

  resnet_50.train()
  for i, (train_img, train_label) in enumerate(train_loader):
    # gpu에 할당
    train_img = train_img.to(device)
    train_label = train_label.to(device)
    optimizer.zero_grad( set_to_none = True ) # 계산했던 가중치 초기화

    output = resnet_50(train_img) # 모델에 입력
    loss = criterion(output, train_label)
    loss.backward() # 미분
    optimizer.step() # 학습

    # loss & acc
    running_loss += loss.item()
    _, predictions = torch.max(output.data ,dim = 1 )
    
    total += train_label.size(0)
    correct += (predictions == train_label).sum().item()
    train_acc += 100 * (correct/total)

  running_loss = round(running_loss/(i+1), 3) # 소수점 반올림
  train_acc = round(train_acc/(i+1), 3)
  
  print(f'Trainset{epoch}/{epochs} Loss : {running_loss}, Accuracy : {train_acc}%')
  train_acc_lst.append(train_acc)
  train_loss_lst.append(running_loss)


  total = 0
  correct = 0
  resnet_50.eval()
  with torch.no_grad():
    for ii, (valid_img, valid_label) in enumerate(valid_loader):
          # gpu에 할당
      valid_img = valid_img.to(device)
      valid_label = valid_label.to(device)

      output = resnet_50(valid_img) # 모델에 입력
      loss = criterion(output, valid_label)

      # loss & acc
      test_running_loss += loss.item()
      _, predictions = torch.max(output.data ,dim = 1 )
      
      total += valid_label.size(0)
      correct += (predictions == valid_label).sum().item()
      test_acc += 100 * (correct/total)

  test_running_loss = round(test_running_loss/(ii+1), 3) # 소수점 반올림
  test_acc = round(test_acc/(ii+1), 3)
  print(f'Validset{epoch}/{epochs} Loss : {test_running_loss}, Accuracy : {test_acc}% \n')
  test_acc_lst.append(test_acc)
  test_loss_lst.append(test_running_loss)

  if np.max(test_acc_lst) <= test_acc: #현재 에포크의 test_acc가 가장 좋은 성능이라면,
    weights = resnet_50.state_dict()  #지금 모델의 가중치를 저장한다.
    check_point = {
        'net' : weights,

        'test_loss' : test_running_loss,
        'triain_loss' : running_loss,

        'train_acc' : train_acc,
        'test_acc' : test_acc,

    }
    torch.save(check_point,save_dir + f'/{model_name}.pth')
# Out:
# Trainset1/100 Loss : 0.823, Accuracy : 55.609%
# Validset1/100 Loss : 0.514, Accuracy : 72.224%
#
# Trainset2/100 Loss : 0.65, Accuracy : 75.971%
# Validset2/100 Loss : 0.685, Accuracy : 66.015%
#
# Trainset3/100 Loss : 0.587, Accuracy : 77.279%
# Validset3/100 Loss : 0.576, Accuracy : 68.239%
#
# Trainset4/100 Loss : 0.575, Accuracy : 75.85%
# Validset4/100 Loss : 0.408, Accuracy : 80.88%
#
# Trainset5/100 Loss : 0.484, Accuracy : 81.886%
# Validset5/100 Loss : 0.416, Accuracy : 76.37%
#
# Trainset6/100 Loss : 0.49, Accuracy : 82.802%
# Validset6/100 Loss : 0.339, Accuracy : 81.941%
#
# Trainset7/100 Loss : 0.466, Accuracy : 81.348%
# Validset7/100 Loss : 0.517, Accuracy : 82.197%
#
# Trainset8/100 Loss : 0.408, Accuracy : 86.041%
# Validset8/100 Loss : 0.505, Accuracy : 72.621%
#
# Trainset9/100 Loss : 0.368, Accuracy : 86.535%
# Validset9/100 Loss : 0.624, Accuracy : 67.596%
#
# Trainset10/100 Loss : 0.413, Accuracy : 83.341%
# Validset10/100 Loss : 0.387, Accuracy : 90.627%
#
# Trainset11/100 Loss : 0.374, Accuracy : 87.429%
# Validset11/100 Loss : 0.308, Accuracy : 83.328%
#
# Trainset12/100 Loss : 0.301, Accuracy : 85.971%
# Validset12/100 Loss : 0.33, Accuracy : 80.569%
#
# Trainset13/100 Loss : 0.351, Accuracy : 87.86%
# Validset13/100 Loss : 0.411, Accuracy : 84.333%
#
# Trainset14/100 Loss : 0.326, Accuracy : 89.593%
# Validset14/100 Loss : 0.369, Accuracy : 78.283%
#
# Trainset15/100 Loss : 0.312, Accuracy : 88.45%
# Validset15/100 Loss : 0.361, Accuracy : 74.396%
#
# Trainset16/100 Loss : 0.277, Accuracy : 90.099%
# Validset16/100 Loss : 0.439, Accuracy : 87.678%
#
# Trainset17/100 Loss : 0.267, Accuracy : 91.73%
# Validset17/100 Loss : 0.438, Accuracy : 81.663%
#
# Trainset18/100 Loss : 0.339, Accuracy : 89.669%
# Validset18/100 Loss : 0.379, Accuracy : 76.805%
#
# Trainset19/100 Loss : 0.251, Accuracy : 90.14%
# Validset19/100 Loss : 0.372, Accuracy : 74.892%
#
# Trainset20/100 Loss : 0.31, Accuracy : 90.115%
# Validset20/100 Loss : 0.344, Accuracy : 84.826%
#
# Trainset21/100 Loss : 0.218, Accuracy : 91.914%
# Validset21/100 Loss : 0.222, Accuracy : 90.764%
#
# Trainset22/100 Loss : 0.239, Accuracy : 93.947%
# Validset22/100 Loss : 0.465, Accuracy : 75.719%
#
# Trainset23/100 Loss : 0.268, Accuracy : 89.743%
# Validset23/100 Loss : 0.454, Accuracy : 74.894%
#
# Trainset24/100 Loss : 0.202, Accuracy : 92.574%
# Validset24/100 Loss : 0.319, Accuracy : 83.755%
#
# Trainset25/100 Loss : 0.221, Accuracy : 92.073%
# Validset25/100 Loss : 0.357, Accuracy : 83.808%
#
# Trainset26/100 Loss : 0.244, Accuracy : 91.355%
# Validset26/100 Loss : 0.369, Accuracy : 82.627%
#
# Trainset27/100 Loss : 0.291, Accuracy : 89.904%
# Validset27/100 Loss : 0.285, Accuracy : 87.2%
#
# Trainset28/100 Loss : 0.214, Accuracy : 92.903%
# Validset28/100 Loss : 0.37, Accuracy : 83.716%
#
# Trainset29/100 Loss : 0.193, Accuracy : 93.666%
# Validset29/100 Loss : 0.318, Accuracy : 86.051%
#
# Trainset30/100 Loss : 0.261, Accuracy : 89.454%
# Validset30/100 Loss : 0.356, Accuracy : 80.742%
#
# Trainset31/100 Loss : 0.164, Accuracy : 95.114%
# Validset31/100 Loss : 0.31, Accuracy : 85.661%
#
# Trainset32/100 Loss : 0.194, Accuracy : 94.434%
# Validset32/100 Loss : 0.294, Accuracy : 84.849%
#
# Trainset33/100 Loss : 0.177, Accuracy : 94.317%
# Validset33/100 Loss : 0.388, Accuracy : 76.96%
#
# Trainset34/100 Loss : 0.224, Accuracy : 91.255%
# Validset34/100 Loss : 0.3, Accuracy : 89.828%
#
# Trainset35/100 Loss : 0.217, Accuracy : 91.973%
# Validset35/100 Loss : 0.279, Accuracy : 81.246%
#
# Trainset36/100 Loss : 0.191, Accuracy : 93.612%
# Validset36/100 Loss : 0.24, Accuracy : 87.044%
#
# Trainset37/100 Loss : 0.17, Accuracy : 93.559%
# Validset37/100 Loss : 0.454, Accuracy : 78.364%
#
# Trainset38/100 Loss : 0.188, Accuracy : 93.503%
# Validset38/100 Loss : 0.364, Accuracy : 83.144%
#
# Trainset39/100 Loss : 0.173, Accuracy : 94.783%
# Validset39/100 Loss : 0.313, Accuracy : 81.782%
#
# Trainset40/100 Loss : 0.144, Accuracy : 94.76%
# Validset40/100 Loss : 0.376, Accuracy : 84.136%
#
# Trainset41/100 Loss : 0.126, Accuracy : 97.362%
# Validset41/100 Loss : 0.422, Accuracy : 82.908%
#
# Trainset42/100 Loss : 0.191, Accuracy : 94.933%
# Validset42/100 Loss : 0.378, Accuracy : 84.039%
#
# Trainset43/100 Loss : 0.149, Accuracy : 95.014%
# Validset43/100 Loss : 0.377, Accuracy : 76.699%
#
# Trainset44/100 Loss : 0.134, Accuracy : 95.032%
# Validset44/100 Loss : 0.428, Accuracy : 83.9%
#
# Trainset45/100 Loss : 0.147, Accuracy : 93.275%
# Validset45/100 Loss : 0.35, Accuracy : 83.404%
#
# Trainset46/100 Loss : 0.202, Accuracy : 94.569%
# Validset46/100 Loss : 0.391, Accuracy : 72.945%
#
# Trainset47/100 Loss : 0.198, Accuracy : 92.84%
# Validset47/100 Loss : 0.332, Accuracy : 82.417%
#
# Trainset48/100 Loss : 0.162, Accuracy : 95.962%
# Validset48/100 Loss : 0.442, Accuracy : 78.92%
#
# Trainset49/100 Loss : 0.201, Accuracy : 92.923%
# Validset49/100 Loss : 0.278, Accuracy : 92.836%
#
# Trainset50/100 Loss : 0.132, Accuracy : 95.988%
# Validset50/100 Loss : 0.388, Accuracy : 71.108%
#
# Trainset51/100 Loss : 0.115, Accuracy : 96.651%
# Validset51/100 Loss : 0.321, Accuracy : 86.089%
#
# Trainset52/100 Loss : 0.162, Accuracy : 94.638%
# Validset52/100 Loss : 0.438, Accuracy : 85.31%
#
# Trainset53/100 Loss : 0.181, Accuracy : 91.099%
# Validset53/100 Loss : 0.364, Accuracy : 80.833%
#
# Trainset54/100 Loss : 0.139, Accuracy : 94.176%
# Validset54/100 Loss : 0.365, Accuracy : 84.804%
#
# Trainset55/100 Loss : 0.185, Accuracy : 93.278%
# Validset55/100 Loss : 0.355, Accuracy : 81.409%
#
# Trainset56/100 Loss : 0.115, Accuracy : 95.502%
# Validset56/100 Loss : 0.256, Accuracy : 93.52%
#
# Trainset57/100 Loss : 0.162, Accuracy : 93.827%
# Validset57/100 Loss : 0.343, Accuracy : 82.019%
#
# Trainset58/100 Loss : 0.102, Accuracy : 97.26%
# Validset58/100 Loss : 0.274, Accuracy : 84.983%
#
# Trainset59/100 Loss : 0.131, Accuracy : 96.334%
# Validset59/100 Loss : 0.383, Accuracy : 84.423%
#
# Trainset60/100 Loss : 0.12, Accuracy : 96.865%
# Validset60/100 Loss : 0.358, Accuracy : 82.304%
#
# Trainset61/100 Loss : 0.147, Accuracy : 96.655%
# Validset61/100 Loss : 0.441, Accuracy : 75.555%
#
# Trainset62/100 Loss : 0.129, Accuracy : 94.946%
# Validset62/100 Loss : 0.311, Accuracy : 85.251%
#
# Trainset63/100 Loss : 0.172, Accuracy : 94.931%
# Validset63/100 Loss : 0.434, Accuracy : 82.055%
#
# Trainset64/100 Loss : 0.103, Accuracy : 96.503%
# Validset64/100 Loss : 0.407, Accuracy : 76.694%
#
# Trainset65/100 Loss : 0.052, Accuracy : 98.398%
# Validset65/100 Loss : 0.422, Accuracy : 84.368%
#
# Trainset66/100 Loss : 0.065, Accuracy : 98.056%
# Validset66/100 Loss : 0.299, Accuracy : 83.513%
#
# Trainset67/100 Loss : 0.071, Accuracy : 97.756%
# Validset67/100 Loss : 0.301, Accuracy : 90.912%
#
# Trainset68/100 Loss : 0.119, Accuracy : 96.192%
# Validset68/100 Loss : 0.46, Accuracy : 76.037%
#
# Trainset69/100 Loss : 0.125, Accuracy : 97.499%
# Validset69/100 Loss : 0.307, Accuracy : 89.852%
#
# Trainset70/100 Loss : 0.109, Accuracy : 96.756%
# Validset70/100 Loss : 0.455, Accuracy : 73.283%
#
# Trainset71/100 Loss : 0.162, Accuracy : 96.408%
# Validset71/100 Loss : 0.557, Accuracy : 81.726%
#
# Trainset72/100 Loss : 0.132, Accuracy : 96.471%
# Validset72/100 Loss : 0.369, Accuracy : 83.568%
#
# Trainset73/100 Loss : 0.112, Accuracy : 95.396%
# Validset73/100 Loss : 0.428, Accuracy : 75.245%
#
# Trainset74/100 Loss : 0.073, Accuracy : 97.339%
# Validset74/100 Loss : 0.405, Accuracy : 81.239%
#
# Trainset75/100 Loss : 0.071, Accuracy : 98.387%
# Validset75/100 Loss : 0.415, Accuracy : 79.577%
#
# Trainset76/100 Loss : 0.105, Accuracy : 96.657%
# Validset76/100 Loss : 0.351, Accuracy : 81.28%
#
# Trainset77/100 Loss : 0.105, Accuracy : 96.306%
# Validset77/100 Loss : 0.436, Accuracy : 86.697%
#
# Trainset78/100 Loss : 0.105, Accuracy : 96.837%
# Validset78/100 Loss : 0.304, Accuracy : 87.858%
#
# Trainset79/100 Loss : 0.054, Accuracy : 97.718%
# Validset79/100 Loss : 0.3, Accuracy : 87.639%
#
# Trainset80/100 Loss : 0.104, Accuracy : 96.974%
# Validset80/100 Loss : 0.358, Accuracy : 86.978%
#
# Trainset81/100 Loss : 0.114, Accuracy : 97.3%
# Validset81/100 Loss : 0.529, Accuracy : 77.413%
#
# Trainset82/100 Loss : 0.162, Accuracy : 95.164%
# Validset82/100 Loss : 0.332, Accuracy : 85.533%
#
# Trainset83/100 Loss : 0.111, Accuracy : 96.776%
# Validset83/100 Loss : 0.393, Accuracy : 86.112%
#
# Trainset84/100 Loss : 0.08, Accuracy : 97.988%
# Validset84/100 Loss : 0.363, Accuracy : 88.349%
#
# Trainset85/100 Loss : 0.067, Accuracy : 97.642%
# Validset85/100 Loss : 0.266, Accuracy : 89.392%
#
# Trainset86/100 Loss : 0.081, Accuracy : 98.103%
# Validset86/100 Loss : 0.298, Accuracy : 84.164%
#
# Trainset87/100 Loss : 0.115, Accuracy : 97.616%
# Validset87/100 Loss : 0.478, Accuracy : 91.33%
#
# Trainset88/100 Loss : 0.095, Accuracy : 95.868%
# Validset88/100 Loss : 0.354, Accuracy : 85.462%
#
# Trainset89/100 Loss : 0.109, Accuracy : 95.837%
# Validset89/100 Loss : 0.384, Accuracy : 81.457%
#
# Trainset90/100 Loss : 0.084, Accuracy : 97.967%
# Validset90/100 Loss : 0.41, Accuracy : 82.226%
#
# Trainset91/100 Loss : 0.092, Accuracy : 98.747%
# Validset91/100 Loss : 0.343, Accuracy : 86.247%
#
# Trainset92/100 Loss : 0.058, Accuracy : 97.449%
# Validset92/100 Loss : 0.436, Accuracy : 82.063%
#
# Trainset93/100 Loss : 0.143, Accuracy : 95.892%
# Validset93/100 Loss : 0.348, Accuracy : 82.985%
#
# Trainset94/100 Loss : 0.092, Accuracy : 96.568%
# Validset94/100 Loss : 0.478, Accuracy : 69.65%
#
# Trainset95/100 Loss : 0.125, Accuracy : 96.128%
# Validset95/100 Loss : 0.375, Accuracy : 80.688%
#
# Trainset96/100 Loss : 0.095, Accuracy : 97.549%
# Validset96/100 Loss : 0.28, Accuracy : 83.422%
#
# Trainset97/100 Loss : 0.135, Accuracy : 95.974%
# Validset97/100 Loss : 0.409, Accuracy : 89.656%
#
# Trainset98/100 Loss : 0.082, Accuracy : 97.707%
# Validset98/100 Loss : 0.279, Accuracy : 89.533%
#
# Trainset99/100 Loss : 0.096, Accuracy : 97.417%
# Validset99/100 Loss : 0.384, Accuracy : 86.945%

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np

fig, axes = plt.subplots(nrows=1, ncols = 2, figsize = (25, 10))

axes[0].plot(np.arange(len(train_acc_lst)), train_acc_lst, label = 'train_acc', linewidth=2)
axes[0].plot(np.arange(len(test_acc_lst)), test_acc_lst, label = 'test_acc', linewidth=2)
axes[0].set_title('Accuracy')
axes[0].legend(loc='best')

axes[1].plot(np.arange(len(train_loss_lst)), train_loss_lst, label = 'train_loss', linewidth=2)
axes[1].plot(np.arange(len(test_loss_lst)), test_loss_lst, label = 'test_loss', linewidth=2)
axes[1].set_title('Loss')
axes[1].legend(loc='best')
